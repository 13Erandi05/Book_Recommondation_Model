# %%
import pandas as pd

my_books = pd.read_csv("liked_books.csv", index_col=0)

# %%
my_books
# Out:
#      user_id   book_id  rating  \
# 0         -1   2517439       5
# 1         -1    113576       5
# 2         -1     35100       5
# 3         -1    228221       5
# 5         -1  17662739       5
# 6         -1    356824       5
# 7         -1  12125412       5
# 8         -1    139069       5
# 10        -1     76680       5
# 11        -1      1898       5
# 12        -1   5096865       5
# 13        -1    228665       5
# 17        -1    437143       5
# 18        -1  18949861       5
# 19        -1   2913377       5
# 20        -1   1215032       5
# 21        -1    883438       5
# 22        -1   5578108       5
# 23        -1    128029       5
# 24        -1     77203       5
# 25        -1      5439       5
# 26        -1   1685995       5
# 27        -1   6448772       5
# 527       -1   8161140       1
# 528       -1     28187       1
# 531       -1  25659450       1
# 532       -1     82599       1
#
#                                                  title
# 0               The Forever War  (The Forever War, #1)
# 1    The Smartest Guys in the Room: The Amazing Ris...
# 2                                Battle Cry of Freedom
# 3                                  The Mask of Command
# 5           2001: A Space Odyssey  (Space Odyssey, #1)
# 6    India After Gandhi: The History of the World's...
# 7      The Lady or the Tiger?: and Other Logic Puzzles
# 8            Endurance: Shackleton's Incredible Voyage
# 10                        Foundation  (Foundation, #1)
# 11   Into Thin Air: A Personal Account of the Mount...
# 12                                       In Cold Blood
# 13       The Eye of the World  (The Wheel of Time, #1)
# 17                A Short History of Nearly Everything
# 18                                             Contact
# 19   The Name of the Wind  (The Kingkiller Chronicl...
# 20   The Wise Man's Fear  (The Kingkiller Chronicle...
# 21                                        East of Eden
# 22   From Colony to Superpower: U.S. Foreign Relati...
# 23                            A Thousand Splendid Suns
# 24                                     The Kite Runner
# 25                             Interpreter of Maladies
# 26                                     Dune  (Dune #1)
# 27   Quantum: Einstein, Bohr, and the Great Debate ...
# 527                                       On the Beach
# 528  The Lightning Thief  (Percy Jackson and the Ol...
# 531                                          Arkwright
# 532                                   Rabbits: A Novel

# %%
my_books["book_id"] = my_books["book_id"].astype(str)

# %%
csv_book_mapping = {}

file_path = "Dataset/book_id_map.csv"

with open(file_path, "r") as f:
  while True:
    line = f.readline()
    if not line:
      break
    csv_id, book_id = line.strip().split(",")
    csv_book_mapping[csv_id] = book_id

# %%
book_set = set(my_books["book_id"])

# %%
overlap_users = {}

file_path_interaction = "Dataset/goodreads_interactions.csv"

with open(file_path_interaction, 'r') as f:
  while True:
    line = f.readline()
    if not line:
      break

    user_id, csv_id, _ , rating, _ = line.strip().split(",")

    book_id = csv_book_mapping.get(csv_id)

    if book_id in book_set:
      if user_id not in overlap_users:
        overlap_users[user_id] = 1
      else:
        overlap_users[user_id] += 1

# %%
len(overlap_users)
# Out:
# 316341

# %%
filter_overlap_users = set([k for k in overlap_users if overlap_users[k] > my_books.shape[0]/5])

# %%
interactions_list = []

with open(file_path_interaction, 'r') as f:
  while True:
    line = f.readline()
    if not line:
      break

    user_id, csv_id, _ , rating, _ = line.strip().split(",")

    if user_id in filter_overlap_users:
      book_id = csv_book_mapping[csv_id]
      interactions_list.append([user_id,book_id,rating])

# %%
interactions = pd.DataFrame(interactions_list, columns=["user_id","book_id","rating"])

# %%
interactions = pd.concat([my_books[["user_id","book_id","rating"]], interactions])

# %%
interactions
# Out:
#         user_id   book_id rating
# 0            -1   2517439      5
# 1            -1    113576      5
# 2            -1     35100      5
# 3            -1    228221      5
# 5            -1  17662739      5
# ...         ...       ...    ...
# 5638696  804100    475178      0
# 5638697  804100    186074      0
# 5638698  804100    153008      0
# 5638699  804100     45107      0
# 5638700  804100   1762198      5
#
# [5638728 rows x 3 columns]

# %%
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])

# %%
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes

# %%
len(interactions["user_index"].unique())
# Out:
# 1259

# %%
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

# %%
len(interactions["book_index"].unique())
# Out:
# 802870

# %%
from scipy.sparse import coo_matrix

rating_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))

# %%
rating_mat_coo
# Out:
# <1259x802870 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5638728 stored elements in COOrdinate format>

# %%
ratings_mat = rating_mat_coo.tocsr()

# %%
interactions[interactions["user_id"]=="-1"]
# Out:
#     user_id   book_id  rating  user_index  book_index
# 0        -1   2517439       5           0      414880
# 1        -1    113576       5           0       38971
# 2        -1     35100       5           0      575858
# 3        -1    228221       5           0      356004
# 5        -1  17662739       5           0      214285
# 6        -1    356824       5           0      581743
# 7        -1  12125412       5           0       59763
# 8        -1    139069       5           0      124430
# 10       -1     76680       5           0      722098
# 11       -1      1898       5           0      276178
# 12       -1   5096865       5           0      625929
# 13       -1    228665       5           0      357774
# 17       -1    437143       5           0      607659
# 18       -1  18949861       5           0      275433
# 19       -1   2913377       5           0      496223
# 20       -1   1215032       5           0       60398
# 21       -1    883438       5           0      767233
# 22       -1   5578108       5           0      637486
# 23       -1    128029       5           0       78172
# 24       -1     77203       5           0      724379
# 25       -1      5439       5           0      633999
# 26       -1   1685995       5           0      188133
# 27       -1   6448772       5           0      671711
# 527      -1   8161140       1           0      742532
# 528      -1     28187       1           0      480322
# 531      -1  25659450       1           0      431105
# 532      -1     82599       1           0      746448

# %%
my_index = 0

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()

# %%
import numpy as np

indices = np.argpartition(similarity, -15)[15:]

# %%
similar_users = interactions[interactions["user_index"].isin(indices)].copy()

# %%
similar_users = similar_users[similar_users["user_id"] != "-1"]

# %%
similar_users
# Out:
#         user_id  book_id  rating  user_index  book_index
# 0           282   627206       4         555      660744
# 1           282      960       4         555      789109
# 2           282    15931       4         555      161780
# 3           282    24178       3         555      393542
# 4           282     6310       4         555      662720
# ...         ...      ...     ...         ...         ...
# 5638696  804100   475178       0        1183      617107
# 5638697  804100   186074       0        1183      258768
# 5638698  804100   153008       0        1183      141428
# 5638699  804100    45107       0        1183      611284
# 5638700  804100  1762198       5        1183      213203
#
# [5500305 rows x 5 columns]

# %%
book_recs = similar_users.groupby("book_id").rating.agg(['count','mean'])

# %%
book_recs
# Out:
#          count      mean
# book_id
# 1          943  3.843054
# 10          45  3.444444
# 100          3  0.000000
# 1000         7  0.571429
# 10000       36  0.250000
# ...        ...       ...
# 9999894      1  0.000000
# 9999908      1  0.000000
# 9999925      9  1.222222
# 999999       4  0.000000
# 9999995      4  1.000000
#
# [793379 rows x 2 columns]

# %%
book_titles = pd.read_json("book_titles.json")
book_titles["book_id"] = book_titles["book_id"].astype(str)

# %%
book_recs = book_recs.merge(book_titles, how="inner", on="book_id")

# %%
book_recs
# Out:
#         book_id  count      mean  \
# 0             1    943  3.843054
# 1            10     45  3.444444
# 2           100      3  0.000000
# 3          1000      7  0.571429
# 4         10000     36  0.250000
# ...         ...    ...       ...
# 669647  9999887      3  2.333333
# 669648  9999894      1  0.000000
# 669649  9999925      9  1.222222
# 669650   999999      4  0.000000
# 669651  9999995      4  1.000000
#
#                                                     title  ratings  \
# 0       Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 1            Harry Potter Collection (Harry Potter, #1-6)    25245
# 2                                Simply Beautiful Beading       75
# 3       Millionaire Women Next Door: The Many Journeys...      460
# 4                                     The Face of Another     2079
# ...                                                   ...      ...
# 669647            Monkey and Elephant's Worst Fight Ever!       66
# 669648                               Questions, Questions      151
# 669649                                     Spring Is Here      479
# 669650                                          Roommates       46
# 669651                                      Cinnamon Baby      142
#
#                                                       url  \
# 0       https://www.goodreads.com/book/show/1.Harry_Po...
# 1       https://www.goodreads.com/book/show/10.Harry_P...
# 2       https://www.goodreads.com/book/show/100.Simply...
# 3       https://www.goodreads.com/book/show/1000.Milli...
# 4       https://www.goodreads.com/book/show/10000.The_...
# ...                                                   ...
# 669647  https://www.goodreads.com/book/show/9999887-mo...
# 669648  https://www.goodreads.com/book/show/9999894-qu...
# 669649  https://www.goodreads.com/book/show/9999925-sp...
# 669650  https://www.goodreads.com/book/show/999999.Roo...
# 669651  https://www.goodreads.com/book/show/9999995-ci...
#
#                                               cover_image  \
# 0       https://images.gr-assets.com/books/1361039191m...
#
# 298944  https://images.gr-assets.com/books/1432278630m...
#
#                                                 mod_title  adjested_count  \
# 331977  a fascination for fish adventures of an underw...        0.428571
# 401212                             follow the polar bears        0.346154
# 283733                            walt disneys cinderella        0.333333
# 375941                                     sammy the seal        0.346154
# 285563                                                           0.271186
# ...                                                   ...             ...
# 299014  harry potter and the order of the phoenix harr...        0.002168
# 97216   harry potter and the sorcerers stone harry pot...        0.001996
# 591454                                 the handmaids tale        0.002049
# 92703      the lord of the rings the lord of the rings 13        0.001446
# 298944  harry potter and the chamber of secrets harry ...        0.001406
#
#            score
# 331977  2.000000
# 401212  1.730769
# 283733  1.666667
# 375941  1.500000
# 285563  1.220339
# ...          ...
# 299014  0.010116
# 97216   0.009481
# 591454  0.008708
# 92703   0.007228
# 298944  0.006095
#
# [394 rows x 10 columns]

# %%
def make_clickable(val):
  return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
  return '<img src="{}" width=50></img>'.format(val)

# %%
top_recs.style.format({'url':make_clickable, 'cover_image':show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_2cadd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cadd_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_2cadd_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_2cadd_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_2cadd_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_2cadd_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_2cadd_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_2cadd_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_2cadd_level0_col7" class="col_heading level0 col7" >mod_title</th>
#       <th id="T_2cadd_level0_col8" class="col_heading level0 col8" >adjested_count</th>
#       <th id="T_2cadd_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cadd_level0_row0" class="row_heading level0 row0" >331977</th>
#       <td id="T_2cadd_row0_col0" class="data row0 col0" >2445888</td>
#       <td id="T_2cadd_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_2cadd_row0_col2" class="data row0 col2" >4.666667</td>
#       <td id="T_2cadd_row0_col3" class="data row0 col3" >A Fascination for Fish: Adventures of an Underwater Pioneer</td>
#       <td id="T_2cadd_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_2cadd_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2445888.A_Fascination_for_Fish">Goodreads</a></td>
#       <td id="T_2cadd_row0_col6" class="data row0 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_2cadd_row0_col7" class="data row0 col7" >a fascination for fish adventures of an underwater pioneer</td>
#       <td id="T_2cadd_row0_col8" class="data row0 col8" >0.428571</td>
#       <td id="T_2cadd_row0_col9" class="data row0 col9" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row1" class="row_heading level0 row1" >401212</th>
#       <td id="T_2cadd_row1_col0" class="data row1 col0" >2853760</td>
#       <td id="T_2cadd_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_2cadd_row1_col2" class="data row1 col2" >5.000000</td>
#       <td id="T_2cadd_row1_col3" class="data row1 col3" >Follow the Polar Bears</td>
#       <td id="T_2cadd_row1_col4" class="data row1 col4" >26</td>
#       <td id="T_2cadd_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2853760-follow-the-polar-bears">Goodreads</a></td>
#       <td id="T_2cadd_row1_col6" class="data row1 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_2cadd_row1_col7" class="data row1 col7" >follow the polar bears</td>
#       <td id="T_2cadd_row1_col8" class="data row1 col8" >0.346154</td>
#       <td id="T_2cadd_row1_col9" class="data row1 col9" >1.730769</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row2" class="row_heading level0 row2" >283733</th>
#       <td id="T_2cadd_row2_col0" class="data row2 col0" >22220611</td>
#       <td id="T_2cadd_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_2cadd_row2_col2" class="data row2 col2" >5.000000</td>
#       <td id="T_2cadd_row2_col3" class="data row2 col3" >Walt Disney's Cinderella</td>
#       <td id="T_2cadd_row2_col4" class="data row2 col4" >27</td>
#       <td id="T_2cadd_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/22220611-walt-disney-s-cinderella">Goodreads</a></td>
#       <td id="T_2cadd_row2_col6" class="data row2 col6" ><img src="https://images.gr-assets.com/books/1407104891m/22220611.jpg" width=50></img></td>
#       <td id="T_2cadd_row2_col7" class="data row2 col7" >walt disneys cinderella</td>
#       <td id="T_2cadd_row2_col8" class="data row2 col8" >0.333333</td>
#       <td id="T_2cadd_row2_col9" class="data row2 col9" >1.666667</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row3" class="row_heading level0 row3" >375941</th>
#       <td id="T_2cadd_row3_col0" class="data row3 col0" >2634243</td>
#       <td id="T_2cadd_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_2cadd_row3_col2" class="data row3 col2" >4.333333</td>
#       <td id="T_2cadd_row3_col3" class="data row3 col3" >Sammy the Seal</td>
#       <td id="T_2cadd_row3_col4" class="data row3 col4" >26</td>
#       <td id="T_2cadd_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2634243-sammy-the-seal">Goodreads</a></td>
#       <td id="T_2cadd_row3_col6" class="data row3 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_2cadd_row3_col7" class="data row3 col7" >sammy the seal</td>
#       <td id="T_2cadd_row3_col8" class="data row3 col8" >0.346154</td>
#       <td id="T_2cadd_row3_col9" class="data row3 col9" >1.500000</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row4" class="row_heading level0 row4" >285563</th>
#       <td id="T_2cadd_row4_col0" class="data row4 col0" >22318047</td>
#       <td id="T_2cadd_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_2cadd_row4_col2" class="data row4 col2" >4.500000</td>
#       <td id="T_2cadd_row4_col3" class="data row4 col3" >টেনিদার অভিযান</td>
#       <td id="T_2cadd_row4_col4" class="data row4 col4" >59</td>
#       <td id="T_2cadd_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/22318047">Goodreads</a></td>
#       <td id="T_2cadd_row4_col6" class="data row4 col6" ><img src="https://images.gr-assets.com/books/1401020110m/22318047.jpg" width=50></img></td>
#       <td id="T_2cadd_row4_col7" class="data row4 col7" > </td>
#       <td id="T_2cadd_row4_col8" class="data row4 col8" >0.271186</td>
#       <td id="T_2cadd_row4_col9" class="data row4 col9" >1.220339</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row5" class="row_heading level0 row5" >597835</th>
#       <td id="T_2cadd_row5_col0" class="data row5 col0" >766128</td>
#       <td id="T_2cadd_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_2cadd_row5_col2" class="data row5 col2" >4.333333</td>
#       <td id="T_2cadd_row5_col3" class="data row5 col3" >And Then It Rained... And Then the Sun Came Out...</td>
#       <td id="T_2cadd_row5_col4" class="data row5 col4" >38</td>
#       <td id="T_2cadd_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/766128.And_Then_It_Rained_And_Then_the_Sun_Came_Out_">Goodreads</a></td>
#       <td id="T_2cadd_row5_col6" class="data row5 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_2cadd_row5_col7" class="data row5 col7" >and then it rained and then the sun came out</td>
#       <td id="T_2cadd_row5_col8" class="data row5 col8" >0.236842</td>
#       <td id="T_2cadd_row5_col9" class="data row5 col9" >1.026316</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row6" class="row_heading level0 row6" >628525</th>
#       <td id="T_2cadd_row6_col0" class="data row6 col0" >852671</td>
#       <td id="T_2cadd_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_2cadd_row6_col2" class="data row6 col2" >4.666667</td>
#       <td id="T_2cadd_row6_col3" class="data row6 col3" >Just for Elephants</td>
#       <td id="T_2cadd_row6_col4" class="data row6 col4" >42</td>
#       <td id="T_2cadd_row6_col5" class="data row6 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/852671.Just_for_Elephants">Goodreads</a></td>
#       <td id="T_2cadd_row6_col6" class="data row6 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_2cadd_row6_col7" class="data row6 col7" >just for elephant
